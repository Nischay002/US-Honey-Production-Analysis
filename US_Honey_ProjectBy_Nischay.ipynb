# %%
import numpy as np
import pandas as pd  #data manipulation
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("/content/US_honey_dataset.csv")
df
# Out:
#       Unnamed: 0         state  colonies_number  yield_per_colony  production  \
# 0              0       Alabama            16000                58      928000
# 1              1       Arizona            52000                79     4108000
# 2              2      Arkansas            50000                60     3000000
# 3              3    California           420000                93    39060000
# 4              4      Colorado            45000                60     2700000
# ...          ...           ...              ...               ...         ...
# 1110        1110      Virginia             6000                40       79000
# 1111        1111    Washington            96000                32     1206000
# 1112        1112  WestVirginia             6000                43      136000
# 1113        1113     Wisconsin            42000                47      750000
# 1114        1114       Wyoming            38000                58      242000
#
# ...

# %%
df["state"].value_counts()
# Out:
# state
# Alabama          27
# Missouri         27
# Arizona          27
# NewJersey        27
# NewYork          27
# NorthCarolina    27
# NorthDakota      27
# Ohio             27
# Oregon           27
# Pennsylvania     27
# SouthDakota      27
# Tennessee        27
# Texas            27
# Utah             27
# Vermont          27
# Virginia         27
# Washington       27
# WestVirginia     27
# Wisconsin        27
# Montana          27
# Nebraska         27
# Mississippi      27
# Minnesota        27
# Arkansas         27
# California       27
# Colorado         27
# Florida          27
# Georgia          27
# Hawaii           27
# Idaho            27
# Illinois         27
# Indiana          27
# Iowa             27
# Kansas           27
# Louisiana        27
# Maine            27
# Michigan         27
# Wyoming          27
# Kentucky         26
# NewMexico        18
# Nevada           15
# SouthCarolina    12
# Oklahoma          9
# Maryland          9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1115 entries, 0 to 1114
# Data columns (total 9 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Unnamed: 0           1115 non-null   int64
#  1   state                1115 non-null   object
#  2   colonies_number      1115 non-null   int64
#  3   yield_per_colony     1115 non-null   int64
#  4   production           1115 non-null   int64
#  5   stocks               1115 non-null   int64
#  6   average_price        1115 non-null   float64
#  7   value_of_production  1115 non-null   int64
#  8   year                 1115 non-null   int64
# dtypes: float64(1), int64(7), object(1)
# memory usage: 78.5+ KB

# %%
df.drop("Unnamed: 0", axis =1,inplace = True)

# %%
df.head()
# Out:
#         state  colonies_number  yield_per_colony  production   stocks  \
# 0     Alabama            16000                58      928000    28000
# 1     Arizona            52000                79     4108000   986000
# 2    Arkansas            50000                60     3000000   900000
# 3  California           420000                93    39060000  4687000
# 4    Colorado            45000                60     2700000  1404000
#
#    average_price  value_of_production  year
# 0           62.0               575000  1995
# 1           68.0              2793000  1995
# 2           64.0              1920000  1995
# 3           60.0             23436000  1995
# 4           68.0              1836000  1995

# %%
#data cleaning--EDA---exploratary data analysis
#dealing with null values
#dealing with dupliucate vslues
#outliers

# %%
df.isnull().sum()
# Out:
# state                  0
# colonies_number        0
# yield_per_colony       0
# production             0
# stocks                 0
# average_price          0
# value_of_production    0
# year                   0
# dtype: int64

# %%
#duplicate
df.duplicated().sum()
# Out:
# 0

# %%
#data visulization
df.columns
# Out:
# Index(['state', 'colonies_number', 'yield_per_colony', 'production', 'stocks',
#        'average_price', 'value_of_production', 'year'],
#       dtype='object')

# %%
#state wise production
plt.figure(figsize=(20,8))
sns.barplot(x="state",y="production",data=df,palette= 'dark')
plt.title("state wise production")
plt.xticks(rotation = 90)
plt.show()
# Out:
# <ipython-input-13-28212ce0a67d>:3: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x="state",y="production",data=df,palette= 'dark')

# %% [markdown]
# #1) Which states are rarely contributing to honey production for the last 27 years?
# #2) Which are the top 5 Honey producing states in the US ?

# %% [markdown]
# #BOTTOM 5 and TOP 5 STATES IN US FOR HONEY PRODUCING

# %%
#GROUPBY
states_production = df.groupby('state')['production'].sum().reset_index()
states_production
# Out:
#             state  production
# 0         Alabama    14467000
# 1         Arizona    38844000
# 2        Arkansas    51846000
# 3      California   423876000
# 4        Colorado    32660000
# 5         Florida   280934000
# 6         Georgia    57426000
# 7          Hawaii    15420000
# 8           Idaho    87188000
# 9        Illinois     9864000
# 10        Indiana     9686000
# 11           Iowa    48607000
# 12         Kansas    14138000
# 13       Kentucky     3224000
# 14      Louisiana    60568000
# 15          Maine     4762000
# 16       Maryland     1975000
# 17       Michigan   101063000
# 18      Minnesota   176581000
# 19    Mississippi    21235000
# 20       Missouri    17904000
# 21        Montana   197173000
# 22       Nebraska    63655000
# 23         Nevada     7399000
# 24      NewJersey     6913000
# 25      NewMexico    10082000
# 26        NewYork    78444000
# 27  NorthCarolina     8909000
# 28    NorthDakota   513742000
# 29           Ohio    22485000
# ...

# %%
top_5 = states_production.sort_values(by='production',ascending = False).head()

# %%
top_5
# Out:
#           state  production
# 28  NorthDakota   513742000
# 3    California   423876000
# 34  SouthDakota   355726000
# 5       Florida   280934000
# 21      Montana   197173000

# %%
sns.barplot(x='state',y='production',data=top_5,palette= 'dark')
plt.show()
# Out:
# <ipython-input-27-06e0a2cd1a71>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='state',y='production',data=top_5,palette= 'dark')

# %%
bottom_5 = states_production.sort_values(by='production',ascending = True).head()
bottom_5
# Out:
#             state  production
# 16       Maryland     1975000
# 30       Oklahoma     2055000
# 33  SouthCarolina     2823000
# 13       Kentucky     3224000
# 15          Maine     4762000

# %%
sns.barplot(x='state',y='production',data=bottom_5,palette= 'dark')
plt.show()
# Out:
# <ipython-input-30-81d4e5806c19>:1: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(x='state',y='production',data=bottom_5,palette= 'dark')

# %% [markdown]
# #What is the Change in mean Average price of Honey from 1995 to 2021?

# %%
mean_avg = df.groupby('year')['average_price'].mean()
mean_avg.reset_index()
# Out:
#     year  average_price
# 0   1995      74.840909
# 1   1996      99.568182
# 2   1997      91.325581
# 3   1998      83.720930
# 4   1999      80.325581
# 5   2000      79.023256
# 6   2001      88.465116
# 7   2002     133.204545
# 8   2003     151.068182
# 9   2004     132.350000
# 10  2005     116.341463
# 11  2006     134.341463
# 12  2007     140.170732
# 13  2008     160.878049
# 14  2009     176.195122
# 15  2010     192.900000
# 16  2011     216.725000
# 17  2012     236.700000
# 18  2013     260.717949
# 19  2014     282.025000
# 20  2015     292.625000
# 21  2016     291.925000
# 22  2017     302.775000
# 23  2018       3.083500
# 24  2019       2.925500
# 25  2020       3.050000
# 26  2021       3.334250

# %%
74.840909-3.334250
# Out:
# 71.506659

# %%
change_mean = mean_avg.loc[1995]-mean_avg.loc[2021]

# %%
change_mean
# Out:
# 71.5066590909091

# %%
change_mean = mean_avg.loc[2021]-mean_avg.loc[1995]
change_mean
# Out:
# -71.5066590909091

# %% [markdown]
# #Which was the year when production of Honey in wholeUS was the highest?

# %%
highest_pro = df.groupby('year')['production'].sum().reset_index()
highest_pro
# Out:
#     year  production
# 0   1995   210272000
# 1   1996   197995000
# 2   1997   191176000
# 3   1998   219321000
# 4   1999   204585000
# 5   2000   220320000
# 6   2001   185403000
# 7   2002   170732000
# 8   2003   180741000
# 9   2004   182379000
# 10  2005   173857000
# 11  2006   154120000
# 12  2007   147609000
# 13  2008   160096000
# 14  2009   143340000
# 15  2010    44797000
# 16  2011    36550000
# 17  2012    31662000
# 18  2013    37974000
# 19  2014    40990000
# 20  2015    41832000
# 21  2016    40837000
# 22  2017    30478000
# 23  2018    28989000
# 24  2019    40510000
# 25  2020    39412000
# 26  2021    23187000

# %%
highest_pro.sort_values(by = 'production', ascending = False).head(1)
# Out:
#    year  production
# 5  2000   220320000

# %% [markdown]
# #From the above inference we get the production was highest in the year 2000, now let infer which state was having highest contribution in that year

# %%
highest_state = df.groupby(['state','year'])['production'].sum().reset_index()

# %%
highest_state
# Out:
#         state  year  production
# 0     Alabama  1995      928000
# 1     Alabama  1996     1024000
# 2     Alabama  1997      924000
# 3     Alabama  1998     1136000
# 4     Alabama  1999     1156000
# ...       ...   ...         ...
# 1110  Wyoming  2017      186000
# 1111  Wyoming  2018      175000
# 1112  Wyoming  2019      306000
# 1113  Wyoming  2020      608000
# 1114  Wyoming  2021      242000
#
# [1115 rows x 3 columns]

# %%
state_2000 = highest_state.loc[(highest_state['year']== 2000)]
state_2000
# Out:
#               state  year  production
# 5           Alabama  2000     1248000
# 32          Arizona  2000     2360000
# 59         Arkansas  2000     5115000
# 86       California  2000    30800000
# 113        Colorado  2000     1740000
# 140         Florida  2000    24360000
# 167         Georgia  2000     3135000
# 194          Hawaii  2000      784000
# 221           Idaho  2000     4700000
# 248        Illinois  2000      488000
# 275         Indiana  2000      520000
# 302            Iowa  2000     2010000
# 329          Kansas  2000     1020000
# 356        Kentucky  2000      144000
# 382       Louisiana  2000     4042000
# 409           Maine  2000      231000
# 436        Maryland  2000      276000
# 445        Michigan  2000     5400000
# 472       Minnesota  2000    13500000
# 499     Mississippi  2000     1224000
# 526        Missouri  2000     1725000
# 553         Montana  2000    12728000
# 580        Nebraska  2000     4350000
# 607          Nevada  2000      350000
# ...

# %%
state_2000.sort_values(by='production',ascending = False).head(1)
# Out:
#            state  year  production
# 721  NorthDakota  2000    33350000

# %% [markdown]
# #6) Which states have the highest no. of colonies in the year 2000?

# %%
df.columns
# Out:
# Index(['state', 'colonies_number', 'yield_per_colony', 'production', 'stocks',
#        'average_price', 'value_of_production', 'year'],
#       dtype='object')

# %%
high_col = df.groupby(['state','year'])['colonies_number'].sum().reset_index()
high_col.head()
# Out:
#      state  year  colonies_number
# 0  Alabama  1995            16000
# 1  Alabama  1996            16000
# 2  Alabama  1997            14000
# 3  Alabama  1998            16000
# 4  Alabama  1999            17000

# %%
state_2000 = high_col.loc[(highest_state['year']== 2000)]
state_2000
# Out:
#               state  year  colonies_number
# 5           Alabama  2000            16000
# 32          Arizona  2000            40000
# 59         Arkansas  2000            55000
# 86       California  2000           440000
# 113        Colorado  2000            29000
# 140         Florida  2000           232000
# 167         Georgia  2000            55000
# 194          Hawaii  2000             7000
# 221           Idaho  2000           100000
# 248        Illinois  2000             8000
# 275         Indiana  2000             8000
# 302            Iowa  2000            30000
# 329          Kansas  2000            15000
# 356        Kentucky  2000             3000
# 382       Louisiana  2000            43000
# 409           Maine  2000            11000
# 436        Maryland  2000             6000
# 445        Michigan  2000            72000
# 472       Minnesota  2000           150000
# 499     Mississippi  2000            17000
# 526        Missouri  2000            23000
# ...

# %%
state_2000.sort_values(by='colonies_number',ascending=False).head(5)
# Out:
#            state  year  colonies_number
# 86    California  2000           440000
# 721  NorthDakota  2000           290000
# 850  SouthDakota  2000           235000
# 140      Florida  2000           232000
# 472    Minnesota  2000           150000
